# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Copy_of_1a_Markdown_About_Me_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About Me - **AbduWakeel**
#
#
# ---
#
#
# <p style= "text-align: center;"> Life is filled with amazing people and amazing things, take a moment for reflection! </p>
#
# <center>
#
# [The Amazing Brain](https://kids.nationalgeographic.com/science/article/your-amazing-brain)
#
# </center>

# %% [markdown]
# ## Find me here
# <span styule="color:#ffbf00">My Linkedin Profile [AbduWakeel](https://www.linkedin.com/in/abduwakeel/)</span>

# %% [markdown]
# ### About Me 😀
#
# ```mermaid
# flowchart TD
#  ```mermaid
# flowchart TD
#     A[Self Starter] --> B{Focused}
#     B -->|Yes| C[Always Available]
#     B -->|No| D[Not Easily Agitated]
#     C --> E[End]
#     D --> F[User Freindly]
#     F --> G{Share Successes}
#     G -->|Yes| C
#     G -->|No| H[Try Again]
#     H --> D

# %% [markdown]
# #### Python
# I ran this code in IPYTHON. It calculates the total investment at 0.07 percent
# return for 10, 20, and 30 years.  You can enter the principal investment as a float value * (1 + r) and multiple by years.  Formatting a line with print("-" * 25) and using .2f for decimal places.
#
# ```# Inital investment
# P = float(input("Enter amount to invest:  $"))
# r = 0.07 # 7% percent return for year
# # calculate for diffrent years
# print("\nYears  |  Amount")
# print("-" * 25)
# for n in [10, 20, 30]:
#     A = P * (1 + r) ** n
#     print(f"{n:^7}  |  ${A:>12,.2F}")
