# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Copy_of_1c_Lists_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lists

# %% [markdown]
# ## Creating lists

# %% [markdown]
# Create a list of numbers with at least 10 numbers and give it a good name

# %%
tricky_numbers = [23, 4, 77, 4, 9, 1, 0, 45, 8, 5 ]
tricky_numbers
# Out:
# [23, 4, 77, 4, 9, 1, 0, 45, 8, 5]

# %% [markdown]
# Create a list of mixed types (integers, floats, strings, lists, etc.)and give it a good name

# %%
mixed_nuts = [0, 2.7, "hello", [34, 21, 65], 3, "yikes", -1, [89],(99 +9), 3]
mixed_nuts
# Out:
# [0, 2.7, 'hello', [34, 21, 65], 3, 'yikes', -1, [89], 108, 3]

# %% [markdown]
# ## Indexing and Slicing

# %% [markdown]
# Access the second item in your mixed types list

# %%
mixed_nuts
# Out:
# [0, 2.7, 'hello', [34, 21, 65], 3, 'yikes', -1, [89], 108, 3]

# %% [markdown]
# Access the 4th-7th items in your list of numbers

# %%
tricky_numbers[4:-2]
# Out:
# [9, 1, 0, 45]

# %% [markdown]
# Access the last 4 items in your mixed types list

# %%
start = 6
end = 10
mixed_nuts[start:end]
# Out:
# [-1, [89], 108, 3]

# %% [markdown]
# ## Exploring

# %%
# @title Python list methods ( from W3Schools )
import pandas as pd

pd.read_html( "https://www.w3schools.com/python/python_ref_list.asp" )[0].style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_17e21" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_17e21_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_17e21_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_17e21_row0_col0" class="data row0 col0" >append()</td>
#       <td id="T_17e21_row0_col1" class="data row0 col1" >Adds an element at the end of the list</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row1_col0" class="data row1 col0" >clear()</td>
#       <td id="T_17e21_row1_col1" class="data row1 col1" >Removes all the elements from the list</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row2_col0" class="data row2 col0" >copy()</td>
#       <td id="T_17e21_row2_col1" class="data row2 col1" >Returns a copy of the list</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row3_col0" class="data row3 col0" >count()</td>
#       <td id="T_17e21_row3_col1" class="data row3 col1" >Returns the number of elements with the specified value</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row4_col0" class="data row4 col0" >extend()</td>
#       <td id="T_17e21_row4_col1" class="data row4 col1" >Add the elements of a list (or any iterable), to the end of the current list</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row5_col0" class="data row5 col0" >index()</td>
#       <td id="T_17e21_row5_col1" class="data row5 col1" >Returns the index of the first element with the specified value</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row6_col0" class="data row6 col0" >insert()</td>
#       <td id="T_17e21_row6_col1" class="data row6 col1" >Adds an element at the specified position</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row7_col0" class="data row7 col0" >pop()</td>
#       <td id="T_17e21_row7_col1" class="data row7 col1" >Removes the element at the specified position</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row8_col0" class="data row8 col0" >remove()</td>
#       <td id="T_17e21_row8_col1" class="data row8 col1" >Removes the first item with the specified value</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row9_col0" class="data row9 col0" >reverse()</td>
#       <td id="T_17e21_row9_col1" class="data row9 col1" >Reverses the order of the list</td>
#     </tr>
#     <tr>
#       <td id="T_17e21_row10_col0" class="data row10 col0" >sort()</td>
#       <td id="T_17e21_row10_col1" class="data row10 col1" >Sorts the list</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Find some list methods that we have not covered in class and try a few out.  You can use the built-in help features to learn what they do.  For more information, you can explore the on-line [documentation]( https://docs.python.org/3.11/library/stdtypes.html#sequence-types-list-tuple-range )

# %%
# list method on numbers list
tricky_numbers.count(1) # looks for a the total number of occurences of a value in this case there are no 3s
# Out:
# 1

# %%
# list method on mixed type list
mixed_nuts.extend("yikes") # extended the argument yikes and will not extend an int or a float
mixed_nuts
# Out:
# [0,
#  2.7,
#  'hello',
#  [34, 21, 65],
#  3,
#  'yikes',
#  -1,
#  [89],
#  108,
#  3,
#  'y',
#  'i',
#  'k',
#  'e',
#  's']
