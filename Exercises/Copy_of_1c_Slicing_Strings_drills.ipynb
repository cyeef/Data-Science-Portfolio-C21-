# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Exercises/Copy_of_1c_Slicing_Strings_drills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Slicing strings exercise

# %% [markdown]
# Below is a quote from a movie.

# %%
line = "Strange women lying in ponds distributing swords is no basis for a system of government."
line
# Out:
# 'Strange women lying in ponds distributing swords is no basis for a system of government.'

# %% [markdown]
# Your task is three-fold:
# 1. pick one of the `outputs` variable
# 1. to come up with a slice syntax so that the result of the slice is the specified output
# 1. to do as many as you can in 5 minutes

# %% [markdown]
# The full collection:

# %%
outputs = {}
outputs[0] = "tubirts"
outputs[1] = "tnemnre"
outputs[2] = "strib"
outputs[3] = "d sdnop"
outputs[4] = "rds i"
outputs[5] = "emow eg"
outputs[6] = "w egnar"
outputs[7] = "sdnop n"
outputs[8] = "ab on s"
outputs[9] = "or a "
outputs[10] = "n si sd"
outputs[11] = "tsys a "
outputs[12] = "s a rof"
outputs[13] = "Stran"
outputs[14] = "nrevog "
outputs[15] = "butin"
outputs[16] = "si sdro"
outputs[17] = "rof sis"
outputs[18] = "f gov"
outputs[19] = "g swo"

# %% [markdown]
# ## Example 1

# %%
outputs[0]
# Out:
# 'tubirts'

# %%
line[-51:-58:-1]
# Out:
# 'tubirts'

# %% [markdown]
# ## Example 2

# %%
print(outputs[19])
x = slice(40,45,1)
print(line[x])
# Out:
# g swo
# g swo

# %% [markdown]
# ## Your turn
