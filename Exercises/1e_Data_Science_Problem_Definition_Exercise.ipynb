# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Exercises/Copy_of_1e_Data_Science_Problem_Definition_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Problem Definition

# %% [markdown]
# For each item develop a well-worded data science problem statement.  Your answer should include what type of data science problem this is ( supervised vs unsupervised ) and then whether it is a classification, regression, or clustering problem.  If it is a supervised problem, you should state what the target of the prediction is.

# %% [markdown]
# 1. Zillow wants you to predict real estate sales prices. They have a large
# database of 12 years of home features accompanied by the corresponding
# sales prices.

# %% [markdown]
# Statement:
#
# { This data-science problem is Numerical/ quantitative and continuous data. Home features can take different values which will help the targeted output - increased home sales (predictively). This supervised ML is a supervised learning path with regression with continous output.  The predictive outcome is that home sales tied to home features that buyers want should increase the value of the home. )

# %% [markdown]
# ---
#
# 2. Amazon wants you to develop a code that upsells (add additional items to the
# customer’s order) based on what items have been viewed and bought by that
# customer over the past 2 years.

# %% [markdown]
# Statement:
#
# { We need to analyze the data as numerical continous data, with a unsupervised model, we don't know if the customer will select the item based upon the suggestions made by the algorithm, this is a constraint on the relationship between inputs, and unlabeled outputs, ML has to learn to connect the dots, data that can come from the consumer if suggested up sales are purchased by the customer. we will see clustering in the model which will give us the ability to tailor the suggestions, the closer the clustering the more predictive the model will be on the types of suggested up sale items the customer may potentially purchase.)

# %% [markdown]
# ---
#
# 3. MGM wants to know what features of a movie seem to increase the movie’s
# box office income. They have a large database of previously released movies
# accompanied by the resulting box office revenue.

# %% [markdown]
# Statement:
#
# { Trends are subject to change, and this is a constraint on the predictability of developing this ML pathway. This numerical data is also continous, we need to identify the categorical features that correlate to the revenue generated by each movie. The MML is supervised because we can determine input independent variable features and target variable revenue. )

# %% [markdown]
# ---
#
# 4. Spotify wants you to develop a method of predicting whether a customer is
# about to terminate their service BEFORE they terminate so that they can offer
# enticements to the customer to keep the service and not terminate (called
# ‘churn’)

# %% [markdown]
# Statement:
#
# { Supervised ML, numerical and discrete data. Our target output is customer cancelation or continuing service. ML can use regression models to predict the causes of churn utilizing the data from previous cancelations to determine what drives the churn, once the patterns are identified, business professionals can determine how to incentivize continued subscriptions after a potential churn.  )

# %% [markdown]
# ---
#
# 5. Comcast wants you to develop a chat bot (automated customer service) to
# take text input and respond with the appropriate help and/or service
# response.

# %% [markdown]
# Statement:
#
# { This is a supervised model, with categorical data.  The customer input will help the model make suggestions relevant to the input.  The clusters will indicate if issues are very similar in the customer base, this will help our target output which will be accuracy in the chatbot suggestions.)

# %% [markdown]
# ---
#
# 6. Instagram wants you to analyze images and output whether the image
# contains people, animals, scenery, or some other subject.

# %% [markdown]
# Statement:
#
# {Supervised classification ML because the data is present and the target output is correctly identifying the images and classifying them correctly. )
