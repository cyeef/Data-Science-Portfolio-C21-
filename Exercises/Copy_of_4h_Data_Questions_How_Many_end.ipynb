# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Exercises/Copy_of_4h_Data_Questions_How_Many_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Titatanic
# Given a table of data, how many ... ?
#
# - columns: 12
#   - identifier columns: 3 PassengerID, Ticket and Name
#   - target columns: 1 -
#    Survived colum has no nulls in the rowos 0
#   - feature columns: 8
#     - rows with nulls in each:
#     - Age        177 (this column has 714 non nulls)
#     - Cabin      687 (this column has 204 non nulls)
#     - Embarked     2  (this column has 891 non nulls)
#
#   - numerical columns: 5
#     - discreet columns:  3 + 1 target
#       - Pclass, Parch, Sibsp
#       - rows with nulls in each: length
#     - continuous columns: 2
#       - rows with nulls in each: yes
#       - Age   177 / 891(rows) * 100 = 20%
#       -
#       - Fare   O nulls
#
#   - categorical columns: 4
#     - nominal columns: 2
#     - male and female
#       - Cabin 687 / 891 * 100 = 77%
#       - Embarked  2 / 891 * 100 = 0.2
#     -  emabarked has S, C, Q as nominal
#       - rows with nulls in each: yes
#         --emabarked: 2
#
#     - ordinal columns:
#       - rows with nulls in each: yes
#       - categories in each:
#       -Pclass is 3 catagories (1, 2,3)
#   - nested columns:
# - rows: 891
#   - rows with nulls: yes - Age, Cabin, and Embarked
#   - duplicate rows: 16
#   - missing rows: no missing rows
