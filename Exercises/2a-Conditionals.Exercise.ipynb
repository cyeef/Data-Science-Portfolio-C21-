# %% [markdown]
# # Conditionals Exercises

# %% [markdown]
# 1. Print 'A is really BIG!' if a is greater than b.
#
# ```python
# a = 900
# b = 7
# ```

# %%
a = 900
b = 7
a,b
# Out:
# (900, 7)

# %%
if(a>b): print("A is really big")
# Out:
# A is really big

# %% [markdown]
# 2. If a and b are equal print 'These things are the same'.  Otherwise, print 'These things are not the same'.
#
# ```python
# a = 2
# b = 4
# ```

# %%
a = 2
b = 4
a, b
# Out:
# (2, 4)

# %%
if(a == b):
  print('These things are the same')
else:
  print("This things are not the same ")

# %% [markdown]
# 3. If a is greater than b AND b is greater than c, print your own silly sentence.
#
# ```python
# a = 9
# b = 5
# c = 2
# ```

# %%
a = 9
b = 5
c = 6
a, b, c
# Out:
# (9, 5, 6)

# %%
if(a > b < c):
  print("this is my silly statement")
# Out:
# this is my silly statement

# %%
if(a == b):
  print("You are on the right track")
elif  (b < c):
  print("please start over")
else:
  print('what is really going on')
# Out:
# please start over

# %%
if(a == b):
  print("You are on the right track")
elif  (b > c):
  print("please start over")
else:
  print('what is really going on')
# Out:
# what is really going on

# %% [markdown]
# 4. If your favorite ice cream is in the list of flavors, print 'I am so happy!'
#
# ```python
# flavors = [
#   'chocolate',
#   'vanilla',
#   'strawberry',
#   'chocolate-chip',
#   "Ben and Jerry's Half-Baked",
# ]
# ```

# %%
flavors = [
  'chocolate',
  'vanilla',
  'strawberry',
  'chocolate-chip',
  "Ben and Jerry's Half-Baked",
  'Cookies and Cream',

]
flavors
# Out:
# ['chocolate',
#  'vanilla',
#  'strawberry',
#  'chocolate-chip',
#  "Ben and Jerry's Half-Baked",
#  'Cookies and Cream']

# %%
if 'Cookies and Cream' in flavors:
  print("I'm so happy")
else:
 print('to bad for your, you aint got no ice creame')
# Out:
# I'm so happy

# %% [markdown]
# 5. Make a list called mypets with your pets (real or imaginary) as elements.
# - if mypets contains 'dog' and 'cat', print 'I am a dog person and a cat person'
# - else if mypets contains 'dog', print 'I am a dog person'
# - else if mypets contains 'cat', print 'I am a cat person'
# - otherwise, print 'I am not a cat person or a dog person'
#
# ```python
# mypets = [  ]
# ```

# %%
mypets = [   'snake', 'chicken']
mypets.insert(0,'dog')   # insert takes two arguments, positon and item
mypets.insert( 1, 'pigeon') #inserted pigeon into position 1
mypets.append("goldfish") # appended goldifsh to the last position

# %%
print(mypets)

if 'dog' in mypets and 'cat' in mypets:
  print( 'Im a dog and cat persons') #this will always evaluate to true dog and cats are present
elif 'dog' in mypets:
  print('Im a dog person') # only if dog is present in the list
elif 'cat' in mypets:
  print('Im a cat person') # only if cat is present in the lisy
else:
  print("I'm not a cat person or a dog person") # this will be reached if neither cat or dog is in the list
# Out:
# ['dog', 'pigeon', 'snake', 'chicken', 'goldfish']
# Im a dog person
