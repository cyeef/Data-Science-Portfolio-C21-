# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Exercises/6a-Numpy%2CPandas%2CPlotting.Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Exercises - Numpy, Pandas & Plotting

# %% [markdown]
# ## Setup: import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Create a pandas dataframe that contains the following columns:
#
# Column Name | Values
# --- | ---
# A | 500 random numbers drawn from a normal distribution with mean 15 and standard deviation 5
# B | 500 equally spaced numbers between 1 and 50 (inclusive)
# C | 500 random integers drawn between 10 and 30 (inclusive)

# %%
df = pd.DataFrame({
    'A': np.random.normal(15, 5, 500),
    'B': np.linspace(1, 50, 500),
    'C': np.random.randint(10, 31, 500)
})

print(df.shape)
print(df.head())
# Out:
# (500, 3)
#            A         B   C
# 0  21.851547  1.000000  30
# 1  13.259957  1.098196  27
# 2   5.198138  1.196393  29
# 3  14.898729  1.294589  20
# 4  16.839451  1.392786  22

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Calculate the mean of column A.

# %%
value = df['A'].mean()
print(df['A'].mean())
# Out:
# 14.886602591016743

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Plot a histogram of column A. It should contain a vertical line at the mean. Make the figure size (10,5). Make sure to add axis labels and a legend for the mean.

# %%
# Histogram
plt.figure(figsize=(10, 5))

# Plot the histogram
plt.hist(df['A'], bins=15, color='black', edgecolor='skyblue', alpha=0.7, label='Column A Data')

# Mean at red line
plt.axvline(value, color='red', linestyle='dashed', linewidth=2, label=f'Mean ({value:.2f})')

# Graph info
plt.xlabel('Values of Column A')
plt.ylabel('Frequency')
plt.title('Histogram Distribution of Column A with Mean Line')
plt.legend()

# output
plt.show()

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Create a line plot of the first 100 values in column C. Make sure to add axis labels.

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['C'][None:100], color= 'green')
plt.title('First 100 Values')
plt.xlabel('Numbers')
plt.ylabel('Random Integer')
plt.show()

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Create a new column, `D`, that contains 3 times the values in column `B` plus some random noise (`np.random.normal(0,10,500`).

# %%
# generated random numbers
df['D'] = (3 * df['B']) + np.random.normal(0, 10, 500)
print(df['D'])
# Out:
# 0       11.819603
# 1        2.534124
# 2       -3.300522
# 3        6.414667
# 4        0.640609
#           ...
# 495    156.189154
# 496    158.113898
# 497    151.898568
# 498    131.180684
# 499    135.124110
# Name: D, Length: 500, dtype: float64

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Create a scatter plot with column `B` on the x-axis and column `D` on the y-axis.  Make sure to add axis labels.

# %%
# Scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(df['B'], df['D'],color= 'orange')
plt.title('500 Numbers')
plt.xlabel('B')
plt.ylabel('D')
plt.show()

# %% [markdown]
# ## **BONUS** (only if you have time)

# %% [markdown]
# Create a new column, `E`, that that contains 3 times the values in column `B` plus some random noise with a smaller standard deviation (`np.random.normal(0,3,500`).  Add the points you generated for column `E` to the scatterplot you created in #5. Use a different color and marker for these points and add a legend.

# %%
df['E'] = (3 * df['B']) + np.random.normal(0, 3, 500)

# %%
plt.scatter(df['B'], df['D'], color='pink', marker='o', alpha=0.6, label='Column D (Noise SD=10)')

# Plot Column B vs Column E
plt.scatter(df['B'], df['E'], color='purple', marker='s', alpha=0.6, label='Column E (Noise SD=3)')

# Graph info
plt.xlabel('B')
plt.ylabel('Values (3 * B + Noise)')
plt.title('Column B vs Columns D and E')
plt.legend()

# output
plt.show()
