# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/copy_of_1d_intro_to_python_lists_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Exercises - Intro to Python & Lists

# %% [markdown]
# ## Working with lists

# %% [markdown]
# 1. Use a variable to represent a famous person’s name and then print that person’s name in lowercase, uppercase and title case.

# %%
kind = 'Betty_Boop'
kind.lower(),kind.upper(),kind.title()
# Out:
# ('betty_boop', 'BETTY_BOOP', 'Betty_Boop')

# %% [markdown]
# 2. Print a message about the person you defined above using an f-string.

# %%
print(f"The coolest female cartoon all time was and is {kind}!")
# Out:
# The coolest female cartoon all time was and is Betty_Boop!

# %% [markdown]
# 3. Store the names of at least 5 of your favorite movies in a list called `movies`.

# %%
movies = ["Apocolypse Now", "Shining", "One Flew Over Cuckoos Nest", "Heat", "Scarface"]
movies
# Out:
# ['Apocolypse Now', 'Shining', 'One Flew Over Cuckoos Nest', 'Heat', 'Scarface']

# %% [markdown]
# 4. Remove one of the movies from your `movies` list.

# %%
movies.remove("Shining")
movies
# Out:
# ['Apocolypse Now', 'One Flew Over Cuckoos Nest', 'Heat', 'Scarface']

# %% [markdown]
# 5. Sort your `movies` list in reverse alphabetical order.

# %%
movies.sort(reverse = True)
movies
# Out:
# ['Scarface', 'One Flew Over Cuckoos Nest', 'Heat', 'Apocolypse Now']

# %% [markdown]
# 6. Use a slice to access the first 3 of your favorite movies.

# %%
movies.sort(reverse = False)
movies[0:3]
# Out:
# ['Apocolypse Now', 'Heat', 'One Flew Over Cuckoos Nest']

# %% [markdown]
# 7. Add your least favorite movie to your `movies` list.

# %%
movies.append("Broke Back Moutain")
movies[0:5]
# Out:
# ['Apocolypse Now',
#  'Heat',
#  'One Flew Over Cuckoos Nest',
#  'Scarface',
#  'Broke Back Moutain']

# %% [markdown]
# 8. Convert the float `16.4` to an integer.

# %%
int(16.4)
# Out:
# 16

# %% [markdown]
# ## Challenge (only if you have time)

# %% [markdown]
# 1. Create a variable called `birthday` and set it equal to the string `'Happy Birthday to You!'`. Use slicing to access every other character in the variable `birthday`.
#
# Hints:
# - w3schools [slicing strings]( https://www.w3schools.com/python/python_strings_slicing.asp )
# - "Automate the Boring Stuff" [slicing strings]( https://automatetheboringstuff.com/3e/chapter8.html#:~:text=valid%20Python%20code.-,Indexes%20and%20Slices,-Strings%20use%20indexes )

# %%
birthday = 'Happy Birthday to You'
birthday[6:14:2]
# Out:
# 'Brha'

# %% [markdown]
# 2. Create a variable called `nested` and set it equal to the following nested list: `[[1,2,3], ['a','b','c']]`. Use indexing to access the `b` from your nested list. Use indexing to access `[2,3]` from your nested list.

# %%
nested =[[1,2,3], ['a', 'b', 'c']]
nested[0][1:], nested[1][1]  # Question?  can you access a nested list as [[],[]] ?
# Out:
# ([2, 3], 'b')
