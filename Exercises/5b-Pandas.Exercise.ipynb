# %% [markdown]
# <a href="https://colab.research.google.com/github/cyeef/Data-Science-Portfolio-C21-/blob/main/Exercises/5b-Pandas.Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Exercises - Pandas

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Imagine three people, e.g. family, friends, cohort.
#
# Create a pandas data frame called `cities_df` that contains the following columns:
#
# * Cities - At least 5 cities in the US
# * States - The states that those cities reside in
# * Region - The region that those cities reside in (NW, SW, Midwest, etc.)
# * Times_1 - The number of times person 1 has been to each city
# * Times_2 - The number of times person 2 has been to each city
# * Times_3 - The number of times person 3 has been to each city

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Define data using a dictionary
data = {
        'Cities'       :   ['New York', 'Mesa', 'Denver', 'Albuquerque', 'Los Angeles', 'Miami'],
        'States'     :   ['New York', 'Arizona', 'Colorado', 'New Mexico', 'California', 'Florida'],
        'Regions'     :   ['North East', 'South West', 'South West', 'South West', 'West', 'South East'],
      'Times_1'      :   [0, 3, 1, 5, 6, 23],
      'Times_2'      :   [23, 10, 8, 5, 9, 0],
      'Times_3'      :   [0, 2, 4, 0, 3, 12],

}

# Create the DataFrame
cities_df = pd.DataFrame(data)
print(cities_df)
# Out:
#         Cities      States     Regions  Times_1  Times_2  Times_3
# 0     New York    New York  North East        0       23        0
# 1         Mesa     Arizona  South West        3       10        2
# 2       Denver    Colorado  South West        1        8        4
# 3  Albuquerque  New Mexico  South West        5        5        0
# 4  Los Angeles  California        West        6        9        3
# 5        Miami     Florida  South East       23        0       12

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Use the `.describe()` and `.info()` methods on your data frame

# %%
cities_df.describe()
# Out:
#          Times_1    Times_2    Times_3
# count   6.000000   6.000000   6.000000
# mean    6.333333   9.166667   3.500000
# std     8.477421   7.678976   4.460942
# min     0.000000   0.000000   0.000000
# 25%     1.500000   5.750000   0.500000
# 50%     4.000000   8.500000   2.500000
# 75%     5.750000   9.750000   3.750000
# max    23.000000  23.000000  12.000000

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Cities   6 non-null      object
#  1   States   6 non-null      object
#  2   Regions  6 non-null      object
#  3   Times_1  6 non-null      int64
#  4   Times_2  6 non-null      int64
#  5   Times_3  6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Use indexing to access the Cities column

# %%
cities_df['Cities']
# Out:
# 0       New York
# 1           Mesa
# 2         Denver
# 3    Albuquerque
# 4    Los Angeles
# 5          Miami
# Name: Cities, dtype: object

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Create a new column called `Total_Times` that contains the total number of times all team members have been to each city.

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Use indexing to access the cities that have been travelled to more than two times.

# %%
cities_df['Total_Times'] = cities_df['Times_1'] + cities_df['Times_2'] + cities_df['Times_3']
print(cities_df)
# Out:
#         Cities      States     Regions  Times_1  Times_2  Times_3  Total_Times
# 0     New York    New York  North East        0       23        0           23
# 1         Mesa     Arizona  South West        3       10        2           15
# 2       Denver    Colorado  South West        1        8        4           13
# 3  Albuquerque  New Mexico  South West        5        5        0           10
# 4  Los Angeles  California        West        6        9        3           18
# 5        Miami     Florida  South East       23        0       12           35

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Make a bar plot with `Cities` on the x axis and `Total_Times` on the y axis.

# %%
cities_df.plot.bar(x='Cities', y=['Total_Times'], figsize=(8, 5))

plt.title('Trips')
plt.ylabel('Total')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Problem 7

# %% [markdown]
# Drop the 'Total_Times' column from your data frame.

# %%
cities_df1 = cities_df.drop('Total_Times', axis=1)
print(cities_df1)
# Out:
#         Cities      States     Regions  Times_1  Times_2  Times_3
# 0     New York    New York  North East        0       23        0
# 1         Mesa     Arizona  South West        3       10        2
# 2       Denver    Colorado  South West        1        8        4
# 3  Albuquerque  New Mexico  South West        5        5        0
# 4  Los Angeles  California        West        6        9        3
# 5        Miami     Florida  South East       23        0       12

# %% [markdown]
# ## Problem 8

# %% [markdown]
# Restructure your data frame using the pandas `.melt()` method. In the `.melt()` method, specify `id_vars = ['Cities', 'States', 'Region']`. Save the melted data frame as a new variable called `cities_df_melted`. Print out `cities_df_melted`.
#
# > Note: make sure to read through the documentation for the `.melt()` method to understand what the method does.

# %%
cities_df_melted = cities_df1.melt(id_vars= ['Cities', 'States', 'Regions'])  # Changes the shape to vertical instead of horizontal
print(cities_df_melted)
# Out:
#          Cities      States     Regions variable  value
# 0      New York    New York  North East  Times_1      0
# 1          Mesa     Arizona  South West  Times_1      3
# 2        Denver    Colorado  South West  Times_1      1
# 3   Albuquerque  New Mexico  South West  Times_1      5
# 4   Los Angeles  California        West  Times_1      6
# 5         Miami     Florida  South East  Times_1     23
# 6      New York    New York  North East  Times_2     23
# 7          Mesa     Arizona  South West  Times_2     10
# 8        Denver    Colorado  South West  Times_2      8
# 9   Albuquerque  New Mexico  South West  Times_2      5
# 10  Los Angeles  California        West  Times_2      9
# 11        Miami     Florida  South East  Times_2      0
# 12     New York    New York  North East  Times_3      0
# 13         Mesa     Arizona  South West  Times_3      2
# 14       Denver    Colorado  South West  Times_3      4
# 15  Albuquerque  New Mexico  South West  Times_3      0
# 16  Los Angeles  California        West  Times_3      3
# 17        Miami     Florida  South East  Times_3     12

# %% [markdown]
# ## Problem 9

# %% [markdown]
# Use the seaborn `barplot()` function to create a barplot of `cities_df_melted` with `Cities` on the x axis, `value` on the y axis and the hue parameter set to `variable`.

# %%
import seaborn as sns
sns.barplot(data = cities_df_melted,
                   x = 'Cities',
                   y = 'value',
                 hue = 'variable')
plt.title('Trips by Person')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
